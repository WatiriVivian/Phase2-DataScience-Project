# %% [markdown]
# ## Final Project Submission
#
# Please fill out:
# * Student name:
# * Student pace: self paced / part time / full time
# * Scheduled project review date/time:
# * Instructor name:
# * Blog post URL:

# %%
#importing the necessary libraries
import pandas as pd

# importing the dataset
kingcounty_df = pd.read_csv("kc_house_data.csv")
kingcounty_df
# Out:
#                id        date     price  bedrooms  bathrooms  sqft_living  \
# 0      7129300520  10/13/2014  221900.0         3       1.00         1180
# 1      6414100192   12/9/2014  538000.0         3       2.25         2570
# 2      5631500400   2/25/2015  180000.0         2       1.00          770
# 3      2487200875   12/9/2014  604000.0         4       3.00         1960
# 4      1954400510   2/18/2015  510000.0         3       2.00         1680
# ...           ...         ...       ...       ...        ...          ...
# 21592   263000018   5/21/2014  360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015  400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014  402101.0         2       0.75         1020
# 21595   291310100   1/16/2015  400000.0         3       2.50         1600
# 21596  1523300157  10/15/2014  325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ...          grade sqft_above  \
# 0          5650     1.0        NaN  NONE  ...      7 Average       1180
# 1          7242     2.0         NO  NONE  ...      7 Average       2170
# 2         10000     1.0         NO  NONE  ...  6 Low Average        770
# 3          5000     1.0         NO  NONE  ...      7 Average       1050
# 4          8080     1.0         NO  NONE  ...         8 Good       1680
# ...         ...     ...        ...   ...  ...            ...        ...
# 21592      1131     3.0         NO  NONE  ...         8 Good       1530
# 21593      5813     2.0         NO  NONE  ...         8 Good       2310
# 21594      1350     2.0         NO  NONE  ...      7 Average       1020
# 21595      2388     2.0        NaN  NONE  ...         8 Good       1600
# 21596      1076     2.0         NO  NONE  ...      7 Average       1020
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 0                0.0     1955           0.0    98178  47.5112 -122.257
# 1              400.0     1951        1991.0    98125  47.7210 -122.319
# 2                0.0     1933           NaN    98028  47.7379 -122.233
# 3              910.0     1965           0.0    98136  47.5208 -122.393
# 4                0.0     1987           0.0    98074  47.6168 -122.045
# ...              ...      ...           ...      ...      ...      ...
# 21592            0.0     2009           0.0    98103  47.6993 -122.346
# 21593            0.0     2014           0.0    98146  47.5107 -122.362
# 21594            0.0     2009           0.0    98144  47.5944 -122.299
# 21595            0.0     2004           0.0    98027  47.5345 -122.069
# 21596            0.0     2008           0.0    98144  47.5941 -122.299
#
#        sqft_living15  sqft_lot15
# 0               1340        5650
# 1               1690        7639
# 2               2720        8062
# 3               1360        5000
# 4               1800        7503
# ...              ...         ...
# 21592           1530        1509
# 21593           1830        7200
# 21594           1020        2007
# 21595           1410        1287
# 21596           1020        1357
#
# [21597 rows x 21 columns]

# %% [markdown]
# # DATA CLEANING

# %%
kingcounty_df.shape
# Out:
# (21597, 21)

# %%
kingcounty_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21597 entries, 0 to 21596
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   id             21597 non-null  int64
#  1   date           21597 non-null  object
#  2   price          21597 non-null  float64
#  3   bedrooms       21597 non-null  int64
#  4   bathrooms      21597 non-null  float64
#  5   sqft_living    21597 non-null  int64
#  6   sqft_lot       21597 non-null  int64
#  7   floors         21597 non-null  float64
#  8   waterfront     19221 non-null  object
#  9   view           21534 non-null  object
#  10  condition      21597 non-null  object
#  11  grade          21597 non-null  object
#  12  sqft_above     21597 non-null  int64
#  13  sqft_basement  21597 non-null  object
#  14  yr_built       21597 non-null  int64
#  15  yr_renovated   17755 non-null  float64
#  16  zipcode        21597 non-null  int64
#  17  lat            21597 non-null  float64
#  18  long           21597 non-null  float64
#  19  sqft_living15  21597 non-null  int64
#  20  sqft_lot15     21597 non-null  int64
# dtypes: float64(6), int64(9), object(6)
# memory usage: 3.5+ MB

# %% [markdown]
# ## Dealing with missing data, duplicates and placeholders
# Currently the following columns in the dataset contain missing data.
# * Water front - 2376,
# * view - 63
# * yr_renovated - 3842

# %%
kingcounty_df.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.159700e+04  2.159700e+04  21597.000000  21597.000000  21597.000000
# mean   4.580474e+09  5.402966e+05      3.373200      2.115826   2080.321850
# std    2.876736e+09  3.673681e+05      0.926299      0.768984    918.106125
# min    1.000102e+06  7.800000e+04      1.000000      0.500000    370.000000
# 25%    2.123049e+09  3.220000e+05      3.000000      1.750000   1430.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    sqft_above      yr_built  yr_renovated  \
# count  2.159700e+04  21597.000000  21597.000000  21597.000000  17755.000000
# mean   1.509941e+04      1.494096   1788.596842   1970.999676     83.636778
# std    4.141264e+04      0.539683    827.759761     29.375234    399.946414
# min    5.200000e+02      1.000000    370.000000   1900.000000      0.000000
# 25%    5.040000e+03      1.000000   1190.000000   1951.000000      0.000000
# 50%    7.618000e+03      1.500000   1560.000000   1975.000000      0.000000
# 75%    1.068500e+04      2.000000   2210.000000   1997.000000      0.000000
# max    1.651359e+06      3.500000   9410.000000   2015.000000   2015.000000
#
#             zipcode           lat          long  sqft_living15     sqft_lot15
# count  21597.000000  21597.000000  21597.000000   21597.000000   21597.000000
# mean   98077.951845     47.560093   -122.213982    1986.620318   12758.283512
# std       53.513072      0.138552      0.140724     685.230472   27274.441950
# min    98001.000000     47.155900   -122.519000     399.000000     651.000000
# 25%    98033.000000     47.471100   -122.328000    1490.000000    5100.000000
# 50%    98065.000000     47.571800   -122.231000    1840.000000    7620.000000
# 75%    98118.000000     47.678000   -122.125000    2360.000000   10083.000000
# max    98199.000000     47.777600   -121.315000    6210.000000  871200.000000

# %%
# droppin the rows missing data
kingcounty_df.dropna(inplace = True)

# %% [markdown]
# Decided that it was easier to drop the rows to avoid losing alot of data and it affecting the regressions.

# %%
kingcounty_df.shape
# Out:
# (15762, 21)

# %% [markdown]
# ### Duplicates

# %%
# checking for duplicates
duplicates = kingcounty_df[kingcounty_df.duplicated(
subset = "id")]
duplicates
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 94     6021501535  12/23/2014   700000.0         3       1.50         1580
# 314    4139480200   12/9/2014  1400000.0         4       3.25         4290
# 718    8820903380    1/2/2015   730000.0         6       2.25         2660
# 837    8682262400   5/13/2015   419950.0         2       1.75         1350
# 1085   9834200885   4/20/2015   550000.0         4       2.50         2080
# ...           ...         ...        ...       ...        ...          ...
# 18977  7856400300   3/22/2015  1510000.0         2       2.50         3180
# 19537   643300040   3/13/2015   719521.0         4       1.75         1920
# 20038  8648900110   8/26/2014   555000.0         3       2.50         1940
# 20165  7853400250   2/19/2015   645000.0         4       3.50         2910
# 20764  6300000226    5/4/2015   380000.0         4       1.00         1200
#
#        sqft_lot  floors waterfront       view  ...         grade sqft_above  \
# 94         5000     1.0         NO       NONE  ...        8 Good       1290
# 314       12103     1.0         NO       GOOD  ...  11 Excellent       2690
# 718       13579     2.0         NO       NONE  ...     7 Average       2660
# 837        4003     1.0         NO       NONE  ...        8 Good       1350
# 1085       4080     1.0         NO       NONE  ...     7 Average       1040
# ...         ...     ...        ...        ...  ...           ...        ...
# 18977      9400     2.0         NO  EXCELLENT  ...  10 Very Good       2610
# 19537      9500     1.0         NO       NONE  ...     7 Average       1470
# 20038      3211     2.0         NO       NONE  ...        8 Good       1940
# 20165      5260     2.0         NO       NONE  ...      9 Better       2910
# 20764      2171     1.5         NO       NONE  ...     7 Average       1200
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 94             290.0     1939           0.0    98117  47.6870 -122.386
# 314           1600.0     1997           0.0    98006  47.5503 -122.102
# 718              0.0     1937        1990.0    98125  47.7142 -122.286
# 837              0.0     2004           0.0    98053  47.7176 -122.033
# 1085          1040.0     1962           0.0    98144  47.5720 -122.290
# ...              ...      ...           ...      ...      ...      ...
# 18977          570.0     1985           0.0    98006  47.5617 -122.158
# 19537          450.0     1966           0.0    98006  47.5683 -122.177
# 20038            0.0     2009           0.0    98027  47.5644 -122.093
# 20165            0.0     2012           0.0    98065  47.5168 -121.883
# 20764            0.0     1933           0.0    98133  47.7076 -122.342
#
#        sqft_living15  sqft_lot15
# 94              1570        4500
# 314             3860       11244
# 718             1120        8242
# 837             1350        4479
# 1085            1340        4080
# ...              ...         ...
# 18977           3760        9450
# 19537           1820       10091
# 20038           1880        3078
# 20165           2910        5260
# 20764           1130        1598
#
# [86 rows x 21 columns]

# %%
# dropping the duplicated data
kingcounty_df.drop_duplicates(subset="id", keep="first", inplace=True)

# %%
kingcounty_df.shape
# Out:
# (15676, 21)

# %% [markdown]
# ### placeholders

# %%
kingcounty_df.sample(n=12)
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 18476  2436700395  10/23/2014   621000.0         3       1.00         1340
# 14863  3274850130   12/3/2014   392000.0         4       2.50         2600
# 15510   461005435    2/2/2015   519000.0         3       1.75         2000
# 2554   2973800030   7/21/2014   175000.0         3       1.00         1030
# 1060   7203220260   7/16/2014  1040000.0         5       3.25         4475
# 15691  1545801410   1/28/2015   276900.0         3       2.50         1620
# 6821   3226049466  12/19/2014   340000.0         2       1.75         1880
# 658     259900160    1/2/2015   748000.0         4       3.50         2770
# 8075    924069176    9/3/2014   710000.0         4       2.75         2710
# 17379  1823099028   7/22/2014   440000.0         3       2.00         1790
# 9702   1321720160    1/2/2015   510000.0         4       3.00         3610
# 16932  2790410250    5/5/2014   615000.0         4       1.75         2300
#
#        sqft_lot  floors waterfront  view  ...         grade sqft_above  \
# 18476      4000     1.5         NO  NONE  ...     7 Average       1340
# 14863      8921     2.0         NO  NONE  ...        8 Good       2600
# 15510      5680     1.0         NO  NONE  ...     7 Average       1080
# 2554       6600     1.0         NO  NONE  ...     7 Average       1030
# 1060       6642     2.0         NO  NONE  ...      9 Better       4475
# 15691      7320     2.0         NO  NONE  ...     7 Average       1620
# 6821       7208     1.0         NO  NONE  ...     7 Average        940
# 658        3330     2.0         NO  NONE  ...        8 Good       1970
# 8075      41811     1.5         NO  NONE  ...        8 Good       1690
# 17379     32379     1.0         NO  NONE  ...     7 Average       1790
# 9702      18948     2.0         NO  NONE  ...  10 Very Good       3610
# 16932     11700     1.0         NO  NONE  ...      9 Better       1960
#
#        sqft_basement yr_built  yr_renovated  zipcode      lat     long  \
# 18476            0.0     1927           0.0    98105  47.6652 -122.288
# 14863            0.0     1991           0.0    98058  47.4423 -122.178
# 15510          920.0     1903           0.0    98117  47.6805 -122.366
# 2554             0.0     1954           0.0    98146  47.4941 -122.340
# 1060             0.0     2014           0.0    98053  47.6849 -122.018
# 15691            0.0     1989           0.0    98038  47.3617 -122.054
# 6821           940.0     1951           0.0    98115  47.6946 -122.328
# 658            800.0     2001           0.0    98052  47.6327 -122.109
# 8075               ?     1995           0.0    98075  47.5836 -122.046
# 17379            0.0     2007           0.0    98045  47.4826 -121.698
# 9702             0.0     1993           0.0    98023  47.2911 -122.342
# 16932          340.0     1977           0.0    98052  47.6331 -122.094
#
#        sqft_living15  sqft_lot15
# 18476           1510        4000
# 14863           2550        8683
# 15510           1230        4535
# 2554            1220        9040
# 1060            3720        6633
# 15691           1550        7686
# 6821            1880        8051
# 658             2180        3380
# 8075            2110       35656
# 17379           2290       43560
# 9702            3568       18948
# 16932           2840       12000
#
# [12 rows x 21 columns]

# %%
# changing the sqft_basement column from categorical to numerical
kingcounty_df["sqft_basement"] = pd.to_numeric(kingcounty_df["sqft_basement"], errors='coerce')
kingcounty_df.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront        object
# view              object
# condition         object
# grade             object
# sqft_above         int64
# sqft_basement    float64
# yr_built           int64
# yr_renovated     float64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
# missing data that was originally in filled by symbols
kingcounty_df["sqft_basement"].isna().sum()
# Out:
# 332

# %% [markdown]
# The sqft_basement is missing **332** data points

# %%
# Drop the missing data in the above column
kingcounty_df.dropna(inplace = True)

# %%
kingcounty_df.shape
# Out:
# (15344, 21)

# %% [markdown]
# Creating a **numerical** column to replace the **categorical** data

# %%
kingcounty_df["view"].unique()
# Out:
# array(['NONE', 'GOOD', 'EXCELLENT', 'AVERAGE', 'FAIR'], dtype=object)

# %%
# create a mapping dictionary
mapping_dict = {"NONE": 1, "FAIR": 2, "AVERAGE": 3, "GOOD": 4, "EXCELLENT": 5,}

# map the ordinal column to the appropriate numerical values
kingcounty_df['view_num'] = kingcounty_df['view'].map(mapping_dict)

# %%
kingcounty_df.head()

# Map 'yes' to 1 and 'no' to 0
kingcounty_df["waterfront_num"] = kingcounty_df["waterfront"].map({'YES': 1, 'NO': 0})                                                

kingcounty_df.head(5)

kingcounty_df.dtypes
# Out:
# id                  int64
# date               object
# price             float64
# bedrooms            int64
# bathrooms         float64
# sqft_living         int64
# sqft_lot            int64
# floors            float64
# waterfront         object
# view               object
# condition          object
# grade              object
# sqft_above          int64
# sqft_basement     float64
# yr_built            int64
# yr_renovated      float64
# zipcode             int64
# lat               float64
# long              float64
# sqft_living15       int64
# sqft_lot15          int64
# view_num            int64
# waterfront_num      int64
# dtype: object

# %%
kingcounty_df['date_column'] = pd.to_datetime(kingcounty_df['date'])
kingcounty_df
# Out:
#                id        date      price  bedrooms  bathrooms  sqft_living  \
# 1      6414100192   12/9/2014   538000.0         3       2.25         2570
# 3      2487200875   12/9/2014   604000.0         4       3.00         1960
# 4      1954400510   2/18/2015   510000.0         3       2.00         1680
# 5      7237550310   5/12/2014  1230000.0         4       4.50         5420
# 8      2414600126   4/15/2015   229500.0         3       1.00         1780
# ...           ...         ...        ...       ...        ...          ...
# 21591  2997800021   2/19/2015   475000.0         3       2.50         1310
# 21592   263000018   5/21/2014   360000.0         3       2.50         1530
# 21593  6600060120   2/23/2015   400000.0         4       2.50         2310
# 21594  1523300141   6/23/2014   402101.0         2       0.75         1020
# 21596  1523300157  10/15/2014   325000.0         2       0.75         1020
#
#        sqft_lot  floors waterfront  view  ... yr_built yr_renovated  zipcode  \
# 1          7242     2.0         NO  NONE  ...     1951       1991.0    98125
# 3          5000     1.0         NO  NONE  ...     1965          0.0    98136
# 4          8080     1.0         NO  NONE  ...     1987          0.0    98074
# 5        101930     1.0         NO  NONE  ...     2001          0.0    98053
# 8          7470     1.0         NO  NONE  ...     1960          0.0    98146
# ...         ...     ...        ...   ...  ...      ...          ...      ...
# 21591      1294     2.0         NO  NONE  ...     2008          0.0    98116
# 21592      1131     3.0         NO  NONE  ...     2009          0.0    98103
# 21593      5813     2.0         NO  NONE  ...     2014          0.0    98146
# 21594      1350     2.0         NO  NONE  ...     2009          0.0    98144
# 21596      1076     2.0         NO  NONE  ...     2008          0.0    98144
#
#            lat     long  sqft_living15  sqft_lot15  view_num  waterfront_num  \
# 1      47.7210 -122.319           1690        7639         1               0
# 3      47.5208 -122.393           1360        5000         1               0
# 4      47.6168 -122.045           1800        7503         1               0
# 5      47.6561 -122.005           4760      101930         1               0
# 8      47.5123 -122.337           1780        8113         1               0
# ...        ...      ...            ...         ...       ...             ...
# 21591  47.5773 -122.409           1330        1265         1               0
# 21592  47.6993 -122.346           1530        1509         1               0
# 21593  47.5107 -122.362           1830        7200         1               0
# 21594  47.5944 -122.299           1020        2007         1               0
# 21596  47.5941 -122.299           1020        1357         1               0
#
#        date_column
# 1       2014-12-09
# 3       2014-12-09
# 4       2015-02-18
# 5       2014-05-12
# 8       2015-04-15
# ...            ...
# 21591   2015-02-19
# 21592   2014-05-21
# 21593   2015-02-23
# 21594   2014-06-23
# 21596   2014-10-15
#
# [15344 rows x 24 columns]
